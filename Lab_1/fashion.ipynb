# %%
#Name: Srinitish Srinivasan
#Register Number: 21BAI1394

# %%
import keras
from keras.datasets import fashion_mnist
import tensorflow as tf 
import numpy as np
import matplotlib.pyplot as plt

# %%
#Load dataset
(train_x,train_y),(test_x,test_y)=fashion_mnist.load_data()

#Preprocessing
train_x=(train_x.reshape((60000,28*28,))/255)
test_x=(test_x.reshape((10000,28*28,))/255)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 4s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
#Convert to one hot
def convert_to_one_hot(label,depth=10):
    encoded=tf.one_hot(label,depth,axis=0)
    
    return encoded

# %%
train_y,test_y=np.array(convert_to_one_hot(train_y)),np.array(convert_to_one_hot(test_y))
train_y,test_y=np.transpose(train_y),np.transpose(test_y)

# %%
#Make Model
nn=tf.keras.Sequential()
nn.add(tf.keras.layers.Dense(units=512,activation='relu',input_shape=(28*28,)))
nn.add(tf.keras.layers.Dense(units=10,activation='softmax'))

# %%
#Compile and Fit
nn.compile(optimizer=tf.keras.optimizers.legacy.Adam(),loss=keras.losses.CategoricalCrossentropy(),metrics=keras.metrics.CategoricalAccuracy())

# %%
learning=nn.fit(train_x,train_y,epochs=25,batch_size=32,verbose=True)
# Out:
# Epoch 1/25
# 1875/1875 [==============================] - 2s 917us/step - loss: 0.4769 - categorical_accuracy: 0.8304
# Epoch 2/25
# 1875/1875 [==============================] - 2s 870us/step - loss: 0.3587 - categorical_accuracy: 0.8698
# Epoch 3/25
# 1875/1875 [==============================] - 2s 941us/step - loss: 0.3212 - categorical_accuracy: 0.8814
# Epoch 4/25
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2986 - categorical_accuracy: 0.8892
# Epoch 5/25
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2779 - categorical_accuracy: 0.8955
# Epoch 6/25
# 1875/1875 [==============================] - 2s 942us/step - loss: 0.2642 - categorical_accuracy: 0.9006
# Epoch 7/25
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2543 - categorical_accuracy: 0.9043
# Epoch 8/25
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2398 - categorical_accuracy: 0.9102
# Epoch 9/25
# 1875/1875 [==============================] - 2s 936us/step - loss: 0.2312 - categorical_accuracy: 0.9134
# Epoch 10/25
# 1875/1875 [==============================] - 2s 956us/step - loss: 0.2194 - categorical_accuracy: 0.9175
# Epoch 11/25
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2114 - categorical_accuracy: 0.9200
# Epoch 12/25
# 1875/1875 [==============================] - 2s 920us/step - loss: 0.2034 - categorical_accuracy: 0.9228
# Epoch 13/25
# 1875/1875 [==============================] - 2s 898us/step - loss: 0.1964 - categorical_accuracy: 0.9254
# Epoch 14/25
# 1875/1875 [==============================] - 2s 879us/step - loss: 0.1886 - categorical_accuracy: 0.9284
# Epoch 15/25
# 1875/1875 [==============================] - 2s 891us/step - loss: 0.1830 - categorical_accuracy: 0.9316
# Epoch 16/25
# 1875/1875 [==============================] - 2s 889us/step - loss: 0.1743 - categorical_accuracy: 0.9348
# Epoch 17/25
# 1875/1875 [==============================] - 2s 909us/step - loss: 0.1712 - categorical_accuracy: 0.9351
# Epoch 18/25
# 1875/1875 [==============================] - 2s 911us/step - loss: 0.1655 - categorical_accuracy: 0.9367
# Epoch 19/25
# 1875/1875 [==============================] - 2s 858us/step - loss: 0.1622 - categorical_accuracy: 0.9388
# Epoch 20/25
# 1875/1875 [==============================] - 2s 859us/step - loss: 0.1573 - categorical_accuracy: 0.9401
# Epoch 21/25
# 1875/1875 [==============================] - 2s 915us/step - loss: 0.1537 - categorical_accuracy: 0.9415
# Epoch 22/25
# 1875/1875 [==============================] - 2s 862us/step - loss: 0.1487 - categorical_accuracy: 0.9435
# Epoch 23/25
# 1875/1875 [==============================] - 2s 860us/step - loss: 0.1444 - categorical_accuracy: 0.9452
# Epoch 24/25
# 1875/1875 [==============================] - 2s 913us/step - loss: 0.1421 - categorical_accuracy: 0.9464
# Epoch 25/25
# 1875/1875 [==============================] - 2s 876us/step - loss: 0.1341 - categorical_accuracy: 0.9498

# %%
plt.plot(learning.history['loss'])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss vs Epoch")
# Out:
# Text(0.5, 1.0, 'Loss vs Epoch')

# %%
plt.plot(learning.history['categorical_accuracy'])
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy vs epoch")
# Out:
# Text(0.5, 1.0, 'Accuracy vs epoch')
